# %%
#! pip install langchain-community fireworks-ai
# Out:
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.12/dist-packages (0.4.1)
# Collecting fireworks-ai
#   Downloading fireworks_ai-0.19.20-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: langchain-core<2.0.0,>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.5)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (1.0.0)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.44)
# Requirement already satisfied: requests<3.0.0,>=2.32.5 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.32.5)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (6.0.3)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (3.13.2)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (8.5.0)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.1.125 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.42)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in /usr/local/lib/python3.12/dist-packages (from langchain-community) (2.0.2)
# Requirement already satisfied: httpx in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (0.28.1)
# Collecting httpx-ws (from fireworks-ai)
#   Downloading httpx_ws-0.8.2-py3-none-any.whl.metadata (9.8 kB)
# Requirement already satisfied: pydantic in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (2.11.10)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (11.3.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (1.109.1)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (4.15.0)
# Collecting mmh3>=4.1.0 (from fireworks-ai)
#   Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl.metadata (14 kB)
# Collecting betterproto-fw>=2.0.3 (from betterproto-fw[compiler]>=2.0.3->fireworks-ai)
#   Downloading betterproto_fw-2.0.3-py3-none-any.whl.metadata (18 kB)
# Collecting asyncstdlib-fw>=3.13.2 (from fireworks-ai)
#   Downloading asyncstdlib_fw-3.13.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: grpcio>=1.71.0 in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (1.76.0)
# Collecting protobuf==5.29.3 (from fireworks-ai)
#   Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl.metadata (592 bytes)
# Collecting rich>=14.0.0 (from fireworks-ai)
#   Downloading rich-14.2.0-py3-none-any.whl.metadata (18 kB)
# Requirement already satisfied: toml>=0.10.2 in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (0.10.2)
# Collecting attrs==23.2.0 (from fireworks-ai)
#   Downloading attrs-23.2.0-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: googleapis-common-protos>=1.60.0 in /usr/local/lib/python3.12/dist-packages (from fireworks-ai) (1.72.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.0)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.4.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.12/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.22.0)
# Collecting aiodns>=3.3.0 (from aiohttp[speedups]>=3.12.11->fireworks-ai)
#   Downloading aiodns-3.5.0-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: Brotli in /usr/local/lib/python3.12/dist-packages (from aiohttp[speedups]>=3.12.11->fireworks-ai) (1.2.0)
# Collecting backports.zstd (from aiohttp[speedups]>=3.12.11->fireworks-ai)
#   Downloading backports_zstd-1.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (6.9 kB)
# Requirement already satisfied: grpclib<0.5.0,>=0.4.1 in /usr/local/lib/python3.12/dist-packages (from betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (0.4.8)
# Requirement already satisfied: python-dateutil<3.0.0,>=2.8.0 in /usr/local/lib/python3.12/dist-packages (from betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (2.9.0.post0)
# Collecting ruff~=0.9.1 (from betterproto-fw[compiler]>=2.0.3->fireworks-ai)
#   Downloading ruff-0.9.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (25 kB)
# Requirement already satisfied: jinja2>=3.0.3 in /usr/local/lib/python3.12/dist-packages (from betterproto-fw[compiler]>=2.0.3->fireworks-ai) (3.1.6)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.1)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: langchain-text-splitters<2.0.0,>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langchain-classic<2.0.0,>=1.0.0->langchain-community) (1.0.0)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (1.33)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<2.0.0,>=1.0.1->langchain-community) (25.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (3.11.4)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (1.0.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.1.125->langchain-community) (0.25.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx->fireworks-ai) (4.11.0)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx->fireworks-ai) (2025.10.5)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx->fireworks-ai) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx->fireworks-ai) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx->fireworks-ai) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->fireworks-ai) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /usr/local/lib/python3.12/dist-packages (from pydantic->fireworks-ai) (2.33.2)
# Requirement already satisfied: typing-inspection>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from pydantic->fireworks-ai) (0.4.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /usr/local/lib/python3.12/dist-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.1)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3.0.0,>=2.32.5->langchain-community) (2.5.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.0.0->fireworks-ai) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=14.0.0->fireworks-ai) (2.19.2)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.2.4)
# Collecting wsproto (from httpx-ws->fireworks-ai)
#   Downloading wsproto-1.3.1-py3-none-any.whl.metadata (5.2 kB)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai->fireworks-ai) (1.9.0)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai->fireworks-ai) (0.12.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai->fireworks-ai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai->fireworks-ai) (4.67.1)
# Collecting pycares>=4.9.0 (from aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai)
#   Downloading pycares-4.11.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (4.5 kB)
# Requirement already satisfied: h2<5,>=3.1.0 in /usr/local/lib/python3.12/dist-packages (from grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (4.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2>=3.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (3.0.3)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.0.1->langchain-community) (3.0.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=14.0.0->fireworks-ai) (0.1.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil<3.0.0,>=2.8.0->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (1.17.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.12/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# Requirement already satisfied: hyperframe<7,>=6.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (6.1.0)
# Requirement already satisfied: hpack<5,>=4.1 in /usr/local/lib/python3.12/dist-packages (from h2<5,>=3.1.0->grpclib<0.5.0,>=0.4.1->betterproto-fw>=2.0.3->betterproto-fw[compiler]>=2.0.3->fireworks-ai) (4.1.0)
# Requirement already satisfied: cffi>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from pycares>=4.9.0->aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai) (2.0.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.5.0->pycares>=4.9.0->aiodns>=3.3.0->aiohttp[speedups]>=3.12.11->fireworks-ai) (2.23)
# Downloading fireworks_ai-0.19.20-py3-none-any.whl (570 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 570.6/570.6 kB 12.9 MB/s eta 0:00:00
# Downloading attrs-23.2.0-py3-none-any.whl (60 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.8/60.8 kB 4.8 MB/s eta 0:00:00
# Downloading protobuf-5.29.3-cp38-abi3-manylinux2014_x86_64.whl (319 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 319.7/319.7 kB 23.6 MB/s eta 0:00:00
# Downloading asyncstdlib_fw-3.13.2-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.9/44.9 kB 3.7 MB/s eta 0:00:00
# Downloading betterproto_fw-2.0.3-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 9.3 MB/s eta 0:00:00
# Downloading mmh3-5.2.0-cp312-cp312-manylinux1_x86_64.manylinux_2_28_x86_64.manylinux_2_5_x86_64.whl (103 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 103.3/103.3 kB 8.7 MB/s eta 0:00:00
# Downloading rich-14.2.0-py3-none-any.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.4/243.4 kB 19.2 MB/s eta 0:00:00
# Downloading httpx_ws-0.8.2-py3-none-any.whl (15 kB)
# Downloading aiodns-3.5.0-py3-none-any.whl (8.1 kB)
# Downloading ruff-0.9.10-py3-none-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 113.9 MB/s eta 0:00:00
# Downloading backports_zstd-1.0.0-cp312-cp312-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (494 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 494.2/494.2 kB 34.0 MB/s eta 0:00:00
# Downloading wsproto-1.3.1-py3-none-any.whl (24 kB)
# Downloading pycares-4.11.0-cp312-cp312-manylinux_2_28_x86_64.whl (641 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 641.1/641.1 kB 26.5 MB/s eta 0:00:00
# Installing collected packages: wsproto, ruff, protobuf, mmh3, backports.zstd, attrs, asyncstdlib-fw, rich, pycares, httpx-ws, betterproto-fw, aiodns, fireworks-ai
#   Attempting uninstall: ruff
#     Found existing installation: ruff 0.14.4
#     Uninstalling ruff-0.14.4:
#       Successfully uninstalled ruff-0.14.4
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.5
#     Uninstalling protobuf-5.29.5:
#       Successfully uninstalled protobuf-5.29.5
#   Attempting uninstall: attrs
#     Found existing installation: attrs 25.4.0
#     Uninstalling attrs-25.4.0:
#       Successfully uninstalled attrs-25.4.0
#   Attempting uninstall: rich
#     Found existing installation: rich 13.9.4
#     Uninstalling rich-13.9.4:
#       Successfully uninstalled rich-13.9.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# bigframes 2.28.0 requires rich<14,>=12.4.4, but you have rich 14.2.0 which is incompatible.
# Successfully installed aiodns-3.5.0 asyncstdlib-fw-3.13.2 attrs-23.2.0 backports.zstd-1.0.0 betterproto-fw-2.0.3 fireworks-ai-0.19.20 httpx-ws-0.8.2 mmh3-5.2.0 protobuf-5.29.3 pycares-4.11.0 rich-14.2.0 ruff-0.9.10 wsproto-1.3.1

# %%
key="enter your key here"
FIREWORKS_API_KEY=key

# %%
import os
from langchain_community.chat_models import ChatFireworks

os.environ["FIREWORKS_API_KEY"] = FIREWORKS_API_KEY

model = ChatFireworks(
    model="accounts/fireworks/models/llama-v3p1-70b-instruct",
    temperature=0
)
# Out:
# /tmp/ipython-input-3597038359.py:6: LangChainDeprecationWarning: The class `ChatFireworks` was deprecated in LangChain 0.0.26 and will be removed in 1.0. An updated version of the class exists in the `langchain-fireworks package and should be used instead. To use it run `pip install -U `langchain-fireworks` and import as `from `langchain_fireworks import ChatFireworks``.
#   model = ChatFireworks(

# %%
model.invoke("Hello, world!")
# Out:
# ERROR:asyncio:Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c60075dddf0>
# AIMessage(content="Hello, world. It's nice to meet you. Is there something I can help you with or would you like to chat?", additional_kwargs={}, response_metadata={'model': 'accounts/fireworks/models/llama-v3p1-70b-instruct', 'finish_reason': 'stop'}, id='lc_run--09605ac6-bf6c-4f82-93ad-fec970f935c6-0')

# %%
model.invoke("tell me recipe of an pear upside down cake")
# Out:
# ERROR:asyncio:Unclosed client session
# client_session: <aiohttp.client.ClientSession object at 0x7c6007388710>
# AIMessage(content="Here's a simple recipe for a delicious Pear Upside-Down Cake:\n\n**Ingredients:**\n\nFor the cake:\n\n* 1 1/2 cups (190g) all-purpose flour\n* 1 cup (200g) granulated sugar\n* 2 teaspoons baking powder\n* 1/2 teaspoon salt\n* 1/2 cup (115g) unsalted butter, softened\n* 1/2 cup (120ml) whole milk\n* 2 large eggs\n* 1 teaspoon pure vanilla extract\n\nFor the caramel topping:\n\n* 1/2 cup (115g) granulated sugar\n* 1/4 cup (60g) light brown sugar\n* 1/2 cup (115g) unsalted butter, cut into small pieces\n* 2-3 ripe pears (Bartlett or Anjou work well), peeled, cored, and sliced into 1/4-inch thick wedges\n\n**Instructions:**\n\n1. **Preheat** your oven to 350°F (180°C). Grease a 10-inch (25cm) tube pan or Bundt pan and set it aside.\n2. **Prepare the caramel topping**: In a small saucepan, combine the granulated sugar, brown sugar, and butter. Place the saucepan over medium heat and cook, stirring occasionally, until the sugar has dissolved.\n3. **Bring the mixture to a boil**, then reduce the heat to medium-low and simmer for about 5 minutes, or until the caramel turns a deep amber color.\n4. **Arrange the pear slices**: In the prepared pan, arrange the pear slices in a single layer, reserving a few slices for the top.\n5. **Pour the caramel mixture**: Pour the caramel mixture evenly over the pear slices.\n6. **Prepare the cake batter**: In a medium bowl, whisk together the flour, sugar, baking powder, and salt.\n7. **Add the wet ingredients**: In a large bowl, whisk together the softened butter, milk, eggs, and vanilla extract.\n8. **Combine the wet and dry ingredients**: Gradually add the dry ingredients to the wet ingredients and mix until just combined.\n9. **Pour the batter**: Pour the cake batter evenly over the pear slices and caramel mixture.\n10. **Arrange the remaining pear slices**: Arrange the reserved pear slices on top of the batter.\n11. **Bake the cake**: Bake the cake for 45-50 minutes, or until a toothpick inserted into the", additional_kwargs={}, response_metadata={'model': 'accounts/fireworks/models/llama-v3p1-70b-instruct', 'finish_reason': 'length'}, id='lc_run--6357907d-0fad-4e7a-a72b-9d685f0c1b95-0')
