# %% [markdown]
# <a href="https://colab.research.google.com/github/vidhi-sys/GenAI_LangChain_and_RAG/blob/main/RAG_Basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#! pip install chromadb

# %%
from google.colab import userdata
import os
os.environ['OPENAI_API_KEY'] = userdata.get('chatgpt')

# %%
#!pip install langchain-community
from langchain_community.document_loaders import WebBaseLoader
# Out:
# Error importing huggingface_hub.hf_file_system: module 'fsspec' has no attribute 'spec'
# Error importing huggingface_hub.hf_file_system: module 'fsspec' has no attribute 'spec'
# WARNING:langchain_community.utils.user_agent:USER_AGENT environment variable not set, consider setting it to identify your requests.

# %% [markdown]
# # WEB SCRAPING - PHYSICS WALLAH SITE
#
# ---

# %%
loader=WebBaseLoader("https://www.pw.live/iit-jee")
docs=loader.load()
print(docs)
# Out:
# [Document(metadata={'source': 'https://www.pw.live/iit-jee', 'title': 'IIT JEE Main And Advanced 2026, Syllabus, Exam Pattern, Exam Dates, Online Courses', 'description': 'Get all the latest updates on IIT JEE 2026 including exam dates, syllabus, eligibility, exam pattern, toppers list, JoSAA counselling, and top engineering colleges. Explore PhysicsWallah’s online coaching for Class 11, 12, and droppers with preparation tips for IIT JEE Main and Advanced.', 'language': 'en'}, page_content="IIT JEE Main And Advanced 2026, Syllabus, Exam Pattern, Exam Dates, Online CoursesAll CoursesCompetitive ExamsIIT JEE,  NEET,  ESE,  GATE,  AE/JE,  OlympiadOnly IASUPSC,  State PSCSchool PreparationFoundation (Class 6-12),  Commerce,  Arts,  CuriousJr (1st - 8th),  Science,  International BoardsGovt ExamJudiciary,  SSC,  Defence,  Teaching,  JAIIB & CAIIB,  BIHAR EXAMS WALLAH,  UP Exams,  Railway,  Nursing Exams,  Banking,  WB ExamsUG & PG Entrance ExamsMBA,  IPMAT,  IIT JAM,  LAW,  CUET UG,  UGC 
# ...

# %% [markdown]
# **TEXT SPLITTING**

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter

text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=200)
texts = text_splitter.split_text(docs[0].page_content)
print(texts[0])
# Out:
# IIT JEE Main And Advanced 2026, Syllabus, Exam Pattern, Exam Dates, Online CoursesAll CoursesCompetitive ExamsIIT JEE,  NEET,  ESE,  GATE,  AE/JE,  OlympiadOnly IASUPSC,  State PSCSchool PreparationFoundation (Class 6-12),  Commerce,  Arts,  CuriousJr (1st - 8th),  Science,  International BoardsGovt ExamJudiciary,  SSC,  Defence,  Teaching,  JAIIB & CAIIB,  BIHAR EXAMS WALLAH,  UP Exams,  Railway,  Nursing Exams,  Banking,  WB ExamsUG & PG Entrance ExamsMBA,  IPMAT,  IIT JAM,  LAW,  CUET UG,  UGC NET,  GMAT,  Design & Architecture,  Pharma,  CUET PG,  NEET PG,  CSIR NETFINANCECA,  CS,  Finance Courses,  ACCAOthersOnline DegreesEnglish Proficiency TestIELTS,  TOEFLAgricultureAgricultureIIT JEENEETESEGATEAE/JEOlympiadVidyapeethPW SkillsPW StoreReal TestClass 1st - 8thPower BatchLogin/RegisterIIT JEEIIT JEE Main And Advanced 2026, Syllabus, Exam Pattern, Exam Dates, Online CoursesGet all the latest updates on IIT JEE 2026 including exam dates, syllabus, eligibility, exam pattern, topper
# ...

# %% [markdown]
# **ADDING TO CHROMAdb**

# %%
from langchain.vectorstores import Chroma
from langchain_openai import OpenAIEmbeddings
vector_store= Chroma.from_texts(texts, OpenAIEmbeddings())
# Out:
# ---------------------------------------------------------------------------
# AuthenticationError                       Traceback (most recent call last)
# /tmp/ipython-input-803341534.py in <cell line: 0>()
#       1 from langchain.vectorstores import Chroma
#       2 from langchain_openai import OpenAIEmbeddings
# ----> 3 vector_store= Chroma.from_texts(texts, OpenAIEmbeddings())
#
# /usr/local/lib/python3.12/dist-packages/langchain_community/vectorstores/chroma.py in from_texts(cls, texts, embedding, metadatas, ids, collection_name, persist_directory, client_settings, client, collection_metadata, **kwargs)
#     841                 documents=texts,
#     842             ):
# --> 843                 chroma_collection.add_texts(
#     844                     texts=batch[3] if batch[3] else [],
#     845                     metadatas=batch[2] if batch[2] else None,
#
# ...

# %%
retriever=vector_store.as_retriever()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipython-input-209007549.py in <cell line: 0>()
# ----> 1 retriever=vector_store.as_retriever()
#
# NameError: name 'vector_store' is not defined

# %%
# !pip install langchain-openai
# Out:
# ...
#   Using cached langchain_core-1.0.7-py3-none-any.whl.metadata (3.6 kB)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.5/82.5 kB 3.0 MB/s eta 0:00:00
# Using cached langchain_core-1.0.7-py3-none-any.whl (472 kB)
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 0.3.80
#     Uninstalling langchain-core-0.3.80:
#       Successfully uninstalled langchain-core-0.3.80
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# langchain-google-genai 2.0.10 requires langchain-core<0.4.0,>=0.3.37, but you have langchain-core 1.0.7 which is incompatible.
# langchain 0.3.27 requires langchain-core<1.0.0,>=0.3.72, but you have langchain-core 1.0.7 which is incompatible.
# langchain 0.3.27 requires langchain-text-splitters<1.0.0,>=0.3.9, but you have langchain-text-splitters 1.0.0 which is incompatible.
# ...

# %%
#!pip install langchain-google-genai google-generativeai
